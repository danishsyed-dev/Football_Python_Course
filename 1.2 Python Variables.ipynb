# %%
#Print String Variable
x = "Ronaldo"
print(x)
# Out:
# Ronaldo

# %%
#Print integer Variable
x = "7"
print(x)
# Out:
# 7

# %%
#Assining Variable in String DataType(Integer is cascaded inside String)
x = str(3)
print(x)
# Out:
# 3

# %%
#for cascading into integer
int(3)
# Out:
# 3

# %%
#for cascading into float
float(3)
# Out:
# 3.0

# %%
#K Sensitive 
A = "Ronaldo"
a = "Messi"
print(A, a)
# Out:
# Ronaldo Messi

# %%
#Variable can not be assign as number example:

10 = 5          #SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
            
            #OR

10_jupiter = 5  #SyntaxError: invalid decimal literal


#To make it work use like this format
Jupyter_10 = 5

# %%
#To Know Data Type use "type()" function:
x = "10"
type(x)
# Out:
# str

# %%
y = 10   # or you can also use int datatype like: y = int(10)
type(y)
# Out:
# int

# %%
float(y)
# Out:
# 10.0

# %%
x = bool(x)
type(x)
# Out:
# bool

# %%
x = 10
bytes(x)
# Out:
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
x = int(5)
y = dict(num=x, name='Ronaldo')
print(y)
print(type(y))
# Out:
# {'num': 5, 'name': 'Ronaldo'}
# <class 'dict'>
