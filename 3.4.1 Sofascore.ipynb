# %%
# !pip install playwright asyncio beautifulsoup4
# !playwright install
# Out:
# ...
#   Using cached greenlet-3.3.2-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/36.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/36.8 MB 578.7 kB/s eta 0:01:03
#     --------------------------------------- 0.8/36.8 MB 670.4 kB/s eta 0:00:54
#     --------------------------------------- 0.8/36.8 MB 670.4 kB/s eta 0:00:54
#    - -------------------------------------- 1.0/36.8 MB 718.9 kB/s eta 0:00:50
#    - -------------------------------------- 1.3/36.8 MB 737.4 kB/s eta 0:00:49
#    - -------------------------------------- 1.3/36.8 MB 737.4 kB/s eta 0:00:49
#    - -------------------------------------- 1.6/36.8 MB 755.5 kB/s eta 0:00:47
# ...

# %%
url = 'https://www.sofascore.com/football/match/atletico-madrid-real-madrid/EgbsLgb#id:14081807'
match_id = url.split('id:')[-1]

# %%
import json
import requests
import pandas as pd

# %%
def main():
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'
    }
    response = requests.get(
        f'https://www.sofascore.com/api/v1/event/{match_id}/shotmap',
        headers=headers
    )
    data = response.json()['shotmap']
    return data

# %%
result = main()
