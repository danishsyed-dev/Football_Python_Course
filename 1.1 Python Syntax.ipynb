# %%
#if you only importing the Pitch, then import this module from mplsoccer
from mpisoccer import Pitch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 #imports Pitch module from mplsoccer
# ----> 2 from mpisoccer import Pitch
#
# ModuleNotFoundError: No module named 'mpisoccer'

# %%
#if you want to import any module then change the name after import
from mpisoccer import Pitch, VerticalPitch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mpisoccer import Pitch, VerticalPitch
#
# ModuleNotFoundError: No module named 'mpisoccer'

# %%
#if you want to import all module
from mpisoccer import *
